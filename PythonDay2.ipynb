# %% [markdown]
# ✅ Problem 1: Collect Student Details (Variables + Input + List)
# Write a Python program that:
#
# Takes the student name as input
# Takes marks for 3 subjects as input
# Stores the marks inside a list called marks
# Prints the name and marks list

# %%
#Problem 1
name=input("Enter Student Name : ")
marks=[]
for i in range(1,4):
  mark=int(input(f"Enter Marks of Subject {i}:"))
  marks.append(mark)

print(f"Student Name is {name}.Marks Optain Are {marks}" )
# Out:
# Enter Student Name : saumya
# Enter Marks of Subject 1:23
# Enter Marks of Subject 2:55
# Enter Marks of Subject 3:13
# Student Name is saumya.Marks Optain Are [23, 55, 13]

# %% [markdown]
# ✅ Problem 2: Calculate Total and Average (Loop + List)
# Using the marks list from Problem 1:
#
# Use a loop to calculate the total marks
# Calculate the average marks
# Print both total and average

# %%
#Problem 2
total=0
for mark in marks:
  total=total+mark
print(f"Total Marks : {total}")
print(f"Average Marks : {total/3}")
# Out:
# Total Marks : 91
# Average Marks : 30.333333333333332

# %% [markdown]
# ✅ Problem 3: Decide Pass or Fail (Conditionals + Loop)
# Using the marks list:
#
# Check if the student has scored 35 or above in all subjects
# If yes → print "Pass"
# If no → print "Fail"

# %%
#Problem 3
result='Pass'
for mark in marks:
  if mark<35:
    result='Fail'
    break
print(result)
# Out:
# Fail

# %% [markdown]
# Problem 4: Create a Student Dictionary (Dictionary + Key-Value Storage)
# Create a dictionary called student that stores:
#
# "name" → student name
# "marks" → list of marks
# "total" → total marks
# "average" → average marks
# "result" → pass/fail

# %%
#Problem 4
Student={
    "Name":name,
    "Marks":marks,
    "Total":total,
    "Average":total/3,
    "Result":result
}
print(Student)
# Out:
# {'Name': 'saumya', 'Marks': [23, 55, 13], 'Total': 91, 'Average': 30.333333333333332, 'Result': 'Fail'}

# %% [markdown]
# ✅ Problem 5: Student Name Short Code (String Slicing)
# Write code that:
#
# Takes the student name
# Extracts and prints the first 3 letters using slicing
# Example:

# %%
#problem 5
print("Name : ",Student.get("Name"))
print("Output :",Student.get("Name")[0:3])
# Out:
# Name :  saumya
# Output :  sau
